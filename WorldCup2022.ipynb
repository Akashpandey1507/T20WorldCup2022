# %% [markdown]
# # T20 World Cup 2022 in Australia EDA Analysis using Python

# %% [markdown]
# Every sports event generates a lot of data which we can use to analyze the performance of players, teams, and many highlights of the game. As the ICC Men’s T20 world cup has just finished, it has generated a lot of data we can use to summarize the event. So, if you want to learn how to analyze a sports event like the t20 world cup, this article is for you. This article will take you through the task of T20 World Cup 2022 analysis using Python.

# %% [markdown]
# The dataset I am using for the T20 World Cup 2022 analysis is collected manually. You can download the dataset from here: https://github.com/Akashpandey1507/T20WorldCup2022

# %% [markdown]
# # Importing Important Liabraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import datetime as dt

# %% [markdown]
# # File Path

# %%
file_path = r'C:\Users\Akash Pandey\Dropbox\My PC (LAPTOP-11T574F4)\Downloads\t20-world-cup-22.csv'

# %% [markdown]
# # Read the Datasets

# %%
original_data = pd.read_csv(file_path)

# %% [markdown]
# # Copy the Datasets

# %%
df = original_data.copy()

# %%
df
# Out:
#                venue         team1         team2       stage   toss winner  \
# 0                SCG   New Zealand     Australia    Super 12     Australia
# 1      Optus Stadium   Afghanistan       England    Super 12       England
# 2   Blundstone Arena       Ireland     Sri lanka    Super 12       Ireland
# 3                MCG      Pakistan         India    Super 12         India
# 4   Blundstone Arena    Bangladesh   Netherlands    Super 12   Netherlands
# 5   Blundstone Arena      Zimbabwe  South Africa    Super 12      Zimbabwe
# 6      Optus Stadium     Sri lanka     Australia    Super 12     Australia
# 7                MCG       Ireland       England    Super 12       England
# 8                MCG   New Zealand   Afghanistan    Super 12           NaN
# 9                SCG  South Africa    Bangladesh    Super 12  South Africa
# 10               SCG         India   Netherlands    Super 12         India
# ...

# %% [markdown]
# # Changing the Data Columns

# %%
df.columns = df.columns.str.title()
df.columns
# Out:
# Index(['Venue', 'Team1', 'Team2', 'Stage', 'Toss Winner', 'Toss Decision',
#        'First Innings Score', 'First Innings Wickets', 'Second Innings Score',
#        'Second Innings Wickets', 'Winner', 'Won By', 'Player Of The Match',
#        'Top Scorer', 'Highest Score', 'Best Bowler', 'Best Bowling Figure'],
#       dtype='object')

# %% [markdown]
# # Data Processing

# %%
df.shape
# Out:
# (33, 17)

# %%
df.isnull().sum()
# Out:
# Venue                     0
# Team1                     0
# Team2                     0
# Stage                     0
# Toss Winner               3
# Toss Decision             3
# First Innings Score       3
# First Innings Wickets     3
# Second Innings Score      3
# Second Innings Wickets    3
# Winner                    4
# Won By                    4
# Player Of The Match       4
# Top Scorer                3
# Highest Score             3
# Best Bowler               3
# Best Bowling Figure       3
# dtype: int64

# %%
plt.figure(figsize=(25,10))
plt.title('Status of Null values in datasets', fontsize = 25)


sns.heatmap(df.isnull())

plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Venue                   33 non-null     object
#  1   Team1                   33 non-null     object
#  2   Team2                   33 non-null     object
#  3   Stage                   33 non-null     object
#  4   Toss Winner             30 non-null     object
#  5   Toss Decision           30 non-null     object
#  6   First Innings Score     30 non-null     float64
#  7   First Innings Wickets   30 non-null     float64
#  8   Second Innings Score    30 non-null     float64
#  9   Second Innings Wickets  30 non-null     float64
#  10  Winner                  29 non-null     object
#  11  Won By                  29 non-null     object
#  12  Player Of The Match     29 non-null     object
#  13  Top Scorer              30 non-null     object
# ...

# %%
int_columns = df.select_dtypes(include='float64').columns
int_col = df[int_columns].isnull().sum()
int_col.index
# Out:
# Index(['First Innings Score', 'First Innings Wickets', 'Second Innings Score',
#        'Second Innings Wickets', 'Highest Score'],
#       dtype='object')

# %%
df[int_col.index] = df[int_col.index].fillna(0)

# %%
int_columns = df.select_dtypes(include='float64').columns
df[int_columns].isnull().sum()
# Out:
# First Innings Score       0
# First Innings Wickets     0
# Second Innings Score      0
# Second Innings Wickets    0
# Highest Score             0
# dtype: int64

# %%
obj_columns = df.select_dtypes(include='object').columns
obj  = df[int_columns].isnull().sum()>0
obj.index
# Out:
# Index(['First Innings Score', 'First Innings Wickets', 'Second Innings Score',
#        'Second Innings Wickets', 'Highest Score'],
#       dtype='object')

# %%
df[obj.index] = df[obj.index].fillna('No Tossed')

# %%
obj_columns = df.select_dtypes(include='object').columns
df[int_columns].isnull().sum()
# Out:
# First Innings Score       0
# First Innings Wickets     0
# Second Innings Score      0
# Second Innings Wickets    0
# Highest Score             0
# dtype: int64

# %%
df = df.fillna(0)

# %%
plt.figure(figsize=(25,10))
plt.title('Status of Null values in datasets', fontsize = 25)


sns.heatmap(df.isnull())

plt.show()

# %%
df
# Out:
#                Venue         Team1         Team2       Stage   Toss Winner  \
# 0                SCG   New Zealand     Australia    Super 12     Australia
# 1      Optus Stadium   Afghanistan       England    Super 12       England
# 2   Blundstone Arena       Ireland     Sri lanka    Super 12       Ireland
# 3                MCG      Pakistan         India    Super 12         India
# 4   Blundstone Arena    Bangladesh   Netherlands    Super 12   Netherlands
# 5   Blundstone Arena      Zimbabwe  South Africa    Super 12      Zimbabwe
# 6      Optus Stadium     Sri lanka     Australia    Super 12     Australia
# 7                MCG       Ireland       England    Super 12       England
# 8                MCG   New Zealand   Afghanistan    Super 12           NaN
# 9                SCG  South Africa    Bangladesh    Super 12  South Africa
# 10               SCG         India   Netherlands    Super 12         India
# ...

# %%
df.isnull().sum().sum()
# Out:
# 27

# %% [markdown]
# # Now We are ready to do EDA Analysis.

# %% [markdown]
# # How much which was held in 2022 T20 WorldCup

# %%
print(f'Total Matched played number including cancel due to rain {df.shape[0]}.')
# Out:
# Total Matched played number including cancel due to rain 33.

# %% [markdown]
# # Which Venues hosted most of the matches.

# %%
plt.figure(figsize=(25,10))
plt.title('Venues for hosted matches', fontsize= 25)
plt.xlabel('', fontsize= 20)
plt.ylabel('', fontsize= 20)

count_plot = sns.countplot(data=df, x='Venue')

for p in count_plot.patches:
    count_plot.annotate(format(p.get_height(), '.0f'), (p.get_x() + p.get_width() / 2., p.get_height()), 
    ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points', fontsize=12)

plt.show()

# %% [markdown]
# # Result:
# * SCG and MCG were hosted most of matches in T20 World Cup 2022.

# %% [markdown]
# # Who is the highest match winner from group stage to finale.

# %%
plt.figure(figsize=(25,10))
plt.title('Most Matches Win', fontsize= 25)
plt.xlabel('', fontsize= 20)
plt.ylabel('', fontsize= 20)

count_plot = sns.countplot(data=df, x='Winner')

for p in count_plot.patches:
    count_plot.annotate(format(p.get_height(), '.0f'), (p.get_x() + p.get_width() / 2., p.get_height()), 
    ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points', fontsize=12)

plt.show()

# %% [markdown]
# # Result
# * England is the most match winner in 2022 T20 World Cup with 5 matches.
# * India and Pakistan are 2nd most match winner in T20 World Cup 2022 with 4 and 4 matches respectively.

# %% [markdown]
# # Who is the most toss winner and result of the toss

# %%
plt.figure(figsize=(25,10))
plt.title('Toss win by team', fontsize= 25)
plt.xlabel('', fontsize= 20)
plt.ylabel('', fontsize= 20)

count_plot = sns.countplot(data=df, x='Toss Winner',hue='Toss Decision')

for p in count_plot.patches:
    count_plot.annotate(format(p.get_height(), '.0f'), (p.get_x() + p.get_width() / 2., p.get_height()), 
    ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points', fontsize=12)

plt.show()

# %% [markdown]
# # Result
# * England have won the most of the toss with bat first.

# %% [markdown]
# # Who is the Top Sccorer in T20 World Cup

# %%
Top = df.groupby('Top Scorer')['Highest Score'].sum().reset_index()
Top
# Out:
#           Top Scorer  Highest Score
# 0         Alex Hales           86.0
# 1   Andrew Balbirnie           62.0
# 2         Ben Stokes           52.0
# 3    Colin Ackermann          103.0
# 4       Devon Conway           92.0
# 5      Glenn Maxwell           54.0
# 6     Glenn Phillips          104.0
# 7     Ibrahim Zadran           32.0
# 8        Jos Buttler           73.0
# 9    Kane Williamson           61.0
# 10      Kusal Mendis           68.0
# 11     Lorcan Tucker           71.0
# 12    Marcus Stoinis           59.0
# 13        Max O'Dowd           52.0
# 14   Mohammad Rizwan          106.0
# 15    Najmul Hossain          125.0
# 16   Pathum Nissanka           67.0
# 17   Quinton de Kock           47.0
# 18     Rilee Rossouw          109.0
# 19       Shadab Khan           52.0
# 20       Shan Masood           44.0
# 21  Suryakumar Yadav          129.0
# 22       Virat Kohli          208.0
# 23          de Silva           66.0

# %%
plt.figure(figsize=(25, 10))
plt.title('Highest Run by Individual', fontsize=25)
plt.xlabel('', fontsize=20)
plt.ylabel('', fontsize=20)
plt.xticks(rotation=90, fontsize=15)


line_plot = sns.lineplot(data=Top, x='Top Scorer', y='Highest Score', marker='o', markersize=8
,color='g')

# Remove x-axis and y-axis tick labels

line_plot.set_yticklabels([])

# Add count labels on each data point
for line in line_plot.lines:
    for x, y in zip(line.get_xdata(), line.get_ydata()):
        line_plot.annotate(format(y, '.0f'), (x, y), ha='center', va='bottom', fontsize=12)

plt.show()

# %% [markdown]
# # Result:
# * The King Virat Kohali is most highet runner in T20 World Cup
# * Surya Kumar Yadav is second most highet runner in T20 World Cup
# but Unfortunetly Indian did not played finale.

# %%
plt.figure(figsize=(25, 10))
plt.title('Most win Player Of The Match', fontsize=25)
plt.xlabel('', fontsize=20)
plt.ylabel('', fontsize=20)
plt.xticks(rotation=90)

count_plot = sns.countplot(data=df, x='Player Of The Match')

# Remove y-axis tick labels
count_plot.set_yticklabels([])

for p in count_plot.patches:
    count_plot.annotate(format(p.get_height(), '.0f'), (p.get_x() + p.get_width() / 2., p.get_height()), 
    ha='center', va='center', xytext=(0, 10), textcoords='offset points', fontsize=12)

plt.show()

# %% [markdown]
# # Result
# * There are 5 player whon won most PLayer with 2 times of the match as below
# 1. Virat Kohali from My India
# 2. Sam curran from England
# 3. Taskin Ahmad from Bangladesh
# 4. Surya Kumar Yadav form My India
# 5. Shadab Khan form Pakistan.

# %% [markdown]
# # Who is the best Bowler and best bowler figure

# %%
# Create a figure with two subplots
fig, axes = plt.subplots(1, 2, figsize=(15, 7))

# Plot 1: Bar plot
count_plot1 = sns.countplot(data=df, x='Best Bowler', ax=axes[0])
axes[0].set_title('Best Bowler', fontsize=25)
axes[0].set_xlabel('', fontsize=20)
axes[0].set_ylabel('', fontsize=20)
axes[0].tick_params(axis='x', rotation=90)  # Set rotation in xticks for subplot 1
axes[0].set_yticklabels([])  # Remove y-axis tick labels for subplot 1

# Add count labels on each bar in subplot 1
for p in count_plot1.patches:
    count_plot1.annotate(format(p.get_height(), '.0f'), (p.get_x() + p.get_width() / 2., p.get_height()), 
                         ha='center', va='center', xytext=(0, 10), textcoords='offset points', fontsize=12)

# Plot 2: Bar plot
count_plot2 = sns.countplot(data=df, x='Best Bowling Figure', ax=axes[1])
axes[1].set_title('Best Bowling Figure', fontsize=25)
axes[1].set_xlabel('', fontsize=20)
axes[1].set_ylabel('', fontsize=20)
axes[1].tick_params(axis='x', rotation=90)  # Set rotation in xticks for subplot 2
axes[1].set_yticklabels([])  # Remove y-axis tick labels for subplot 2

# Add count labels on each bar in subplot 2
for p in count_plot2.patches:
    count_plot2.annotate(format(p.get_height(), '.0f'), (p.get_x() + p.get_width() / 2., p.get_height()), 
                         ha='center', va='center', xytext=(0, 10), textcoords='offset points', fontsize=12)

# Adjust the layout spacing between subplots
plt.tight_layout()

# Show the plots
plt.show()

# %% [markdown]
# # Result
# * Sam curran is the best bowler in T20 World Cup 2022.

# %% [markdown]
# # What the best venue for first and second inning score.

# %%
# Create a figure with a single plot
plt.figure(figsize=(25, 10))

# Plotting the first inning scores
sns.barplot(data=df, x='Venue', y='First Innings Score')
plt.title('First Inning Scores by Venue', fontsize=20)
plt.xlabel('Venue', fontsize=15)
plt.ylabel('First Inning Score', fontsize=15)

plt.gca().set_yticklabels([])  # Remove y-axis tick labels

# Add count labels on each bar
for p in plt.gca().patches:
    plt.gca().annotate(format(p.get_height(), '.0f'), (p.get_x() + p.get_width() / 2., p.get_height()),
                       ha='center', va='center', xytext=(0, 10), textcoords='offset points', fontsize=12)

# Show the first plot
plt.show()

# %% [markdown]
# # Result:
# * Best Venue for first in SCG .

# %%
# Create a new figure for the second plot
plt.figure(figsize=(25, 10))

# Plotting the second inning scores
sns.barplot(data=df, x='Venue', y='Second Innings Score')
plt.title('Second Inning Scores by Venue', fontsize=20)
plt.xlabel('Venue', fontsize=15)
plt.ylabel('Second Inning Score', fontsize=15)

plt.gca().set_yticklabels([])  # Remove y-axis tick labels

# Add count labels on each bar
for p in plt.gca().patches:
    plt.gca().annotate(format(p.get_height(), '.0f'), (p.get_x() + p.get_width() / 2., p.get_height()),
                       ha='center', va='center', xytext=(0, 10), textcoords='offset points', fontsize=12)

# Show the second plot
plt.show()

# %% [markdown]
# # Result:
# * Best venue for Second is The Gabba and Adelaide Oval

# %% [markdown]
# # What is the Best result in Winning by Runs Or Wickets.

# %%
plt.figure(figsize=(25, 10))
plt.title('Winning By', fontsize=25)
plt.xlabel('', fontsize=20)
plt.ylabel('', fontsize=20)
plt.xticks(rotation=90)

count_plot = sns.countplot(data=df, x='Won By')

# Remove y-axis tick labels
count_plot.set_yticklabels([])

for p in count_plot.patches:
    count_plot.annotate(format(p.get_height(), '.0f'), (p.get_x() + p.get_width() / 2., p.get_height()), 
    ha='center', va='center', xytext=(0, 10), textcoords='offset points', fontsize=12)

plt.show()

# %% [markdown]
# # Result:
# * The Winning in term of Run is the highest number by team. means that when the team bat in second inning the most won matches.

# %%
df
# Out:
#                Venue         Team1         Team2       Stage   Toss Winner  \
# 0                SCG   New Zealand     Australia    Super 12     Australia
# 1      Optus Stadium   Afghanistan       England    Super 12       England
# 2   Blundstone Arena       Ireland     Sri lanka    Super 12       Ireland
# 3                MCG      Pakistan         India    Super 12         India
# 4   Blundstone Arena    Bangladesh   Netherlands    Super 12   Netherlands
# 5   Blundstone Arena      Zimbabwe  South Africa    Super 12      Zimbabwe
# 6      Optus Stadium     Sri lanka     Australia    Super 12     Australia
# 7                MCG       Ireland       England    Super 12       England
# 8                MCG   New Zealand   Afghanistan    Super 12           NaN
# 9                SCG  South Africa    Bangladesh    Super 12  South Africa
# 10               SCG         India   Netherlands    Super 12         India
# ...

# %% [markdown]
# # The End
